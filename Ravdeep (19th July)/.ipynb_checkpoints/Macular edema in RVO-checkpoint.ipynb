# %% [markdown]
# # Intialisation Steps
# Connecting to Snowflake

# %% [markdown]
# ## Importing required modules

# %%
import pandas as pd
from drg_connect import Snowflake
import qgrid 
from datetime import timedelta, datetime
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Snowflake connection parameter

# %%
##defining parameters of snowflake
snow = Snowflake(role = 'RWD_ANALYTICS_RW',database='SANDBOX_ANALYTICS',schema = 'SANDBOX')
engine = snow.engine

# %reload_ext sql_magic
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine

# %% [markdown]
# # ICD grouper table

# %% [markdown]
# ## Swarali notes:
# - Using level_4_short_description_icd10 variable because description includes retinal vein occlusion and macular edema

# %%
# %%read_sql
#
# create or replace temporary table st_rvo_me_ref1 as
#
# select
#     'dx' as cat1,
#     'all_me' as cat2,
#     case
#         when
#             lower(level_4_long_description_icd10) like '%branch%'
#             then 'brvo'
#         when
#             (lower(level_4_long_description_icd10) like '%retinal%'
#             and lower(level_4_long_description_icd10) like '%vein%'
#             and lower(level_4_long_description_icd10) like '%occlusion%')
#             then 'crvo'
#         when
#             (lower(level_4_long_description_icd10) like '%venous%'
#             and lower(level_4_long_description_icd10) like '%engorgement%'
#             and lower(level_4_long_description_icd10) like '%eye%')
#             then 've'
#         else 'other_me'
#         end as cat3,
#     null as cat4,
#     null as cat5,
#     null as cat6,
#     'icd_10' as type,
#     level_4 as value,
#     level_4_long_description_icd10 as description,
#     current_date() as active_date,
#     'Nish' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER' as source
# from
#     RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# where
#     (lower(level_4_long_description_icd10) like '%retinal%'
#     and lower(level_4_long_description_icd10) like '%vein%'
#     and lower(level_4_long_description_icd10) like '%occlusion%')
#         or
#     (lower(level_4_long_description_icd10) like '%venous%'
#     and lower(level_4_long_description_icd10) like '%engorgement%'
#     and lower(level_4_long_description_icd10) like '%eye%')
#         or
#     (lower(level_4_long_description_icd10) like '%macular%'
#     and lower(level_4_long_description_icd10) like '%edema%'
#     and lower(level_4_long_description_icd10) not like '%without%')
# Out:
# Query started at 04:25:01 PM GMT Daylight TimeInitiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ; Query executed in 0.22 m
#                                        status
# 0  Table ST_RVO_ME_REF1 successfully created.

# %%
# %%read_sql
#
# create or replace temporary table st_rvo_me_ref2 as
#
# select
#     'dx' as cat1,
#     'all_me' as cat2,
#     case
#         when
#             lower(level_4_long_description_icd10) like '%branch%'
#             then 'brvo'
#         when
#             (lower(level_4_long_description_icd10) like '%retinal%'
#             and lower(level_4_long_description_icd10) like '%vein%'
#             and lower(level_4_long_description_icd10) like '%occlusion%')
#             then 'crvo'
#         when
#             (lower(level_4_long_description_icd10) like '%venous%'
#             and lower(level_4_long_description_icd10) like '%engorgement%'
#             and lower(level_4_long_description_icd10) like '%eye%')
#             then 've'
#         else 'other_me'
#         end as cat3,
#     null as cat4,
#     null as cat5,
#     null as cat6,
#     'icd_9' as type,
#     icd9_mapped_codes as value,
#     level_4_long_description_icd10 as description,
#     current_date() as active_date,
#     'Nish' as active_reason,
#     null as deactive_date,
#     null as deactive_reason,
#     'RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER' as source
# from
#     RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# where
#     ((lower(level_4_long_description_icd10) like '%retinal%'
#     and lower(level_4_long_description_icd10) like '%vein%'
#     and lower(level_4_long_description_icd10) like '%occlusion%')
#         or
#     (lower(level_4_long_description_icd10) like '%venous%'
#     and lower(level_4_long_description_icd10) like '%engorgement%'
#     and lower(level_4_long_description_icd10) like '%eye%')
#         or
#     (lower(level_4_long_description_icd10) like '%macular%'
#     and lower(level_4_long_description_icd10) like '%edema%'
#     and lower(level_4_long_description_icd10) not like '%without%'))
#     and icd9_mapped_codes != 'No map'
# Out:
# Query started at 04:25:20 PM GMT Daylight Time; Query executed in 0.11 m
#                                        status
# 0  Table ST_RVO_ME_REF2 successfully created.

# %%
# %%read_sql
#
# create or replace table st_rvo_me_ref as
#
# select * from st_rvo_me_ref1
# union
# select * from st_rvo_me_ref2
# order by type, value, cat3
# Out:
# Query started at 04:35:11 PM GMT Daylight Time; Query executed in 0.11 m
#                                       status
# 0  Table ST_RVO_ME_REF successfully created.

# %% [markdown]
# ## Export ref table to inspect

# %%
snow.select("select * from st_rvo_me_ref")
# Out:
#     cat1    cat2      cat3  cat4  cat5  cat6    type    value  \
# 0     dx  all_me  other_me  None  None  None  icd_10   E08311
# 1     dx  all_me  other_me  None  None  None  icd_10   E08321
# 2     dx  all_me  other_me  None  None  None  icd_10  E083211
# 3     dx  all_me  other_me  None  None  None  icd_10  E083212
# 4     dx  all_me  other_me  None  None  None  icd_10  E083213
# 5     dx  all_me  other_me  None  None  None  icd_10  E083219
# 6     dx  all_me  other_me  None  None  None  icd_10   E08331
# 7     dx  all_me  other_me  None  None  None  icd_10  E083311
# 8     dx  all_me  other_me  None  None  None  icd_10  E083312
# 9     dx  all_me  other_me  None  None  None  icd_10  E083313
# 10    dx  all_me  other_me  None  None  None  icd_10  E083319
# 11    dx  all_me  other_me  None  None  None  icd_10   E08341
# 12    dx  all_me  other_me  None  None  None  icd_10  E083411
# 13    dx  all_me  other_me  None  None  None  icd_10  E083412
# 14    dx  all_me  other_me  None  None  None  icd_10  E083413
# 15    dx  all_me  other_me  None  None  None  icd_10  E083419
# 16    dx  all_me  other_me  None  None  None  icd_10   E08351
# 17    dx  all_me  other_me  None  None  None  icd_10  E083511
# 18    dx  all_me  other_me  None  None  None  icd_10  E083512
# 19    dx  all_me  other_me  None  None  None  icd_10  E083513
# 20    dx  all_me  other_me  None  None  None  icd_10  E083519
# 21    dx  all_me  other_me  None  None  None  icd_10    E0837
# 22    dx  all_me  other_me  None  None  None  icd_10  E0837X1
# 23    dx  all_me  other_me  None  None  None  icd_10  E0837X2
# 24    dx  all_me  other_me  None  None  None  icd_10  E0837X3
# 25    dx  all_me  other_me  None  None  None  icd_10  E0837X9
# 26    dx  all_me  other_me  None  None  None  icd_10   E09311
# 27    dx  all_me  other_me  None  None  None  icd_10   E09321
# 28    dx  all_me  other_me  None  None  None  icd_10  E093211
Drug or chemical induced diabetes mellitus wit...  2018-07-18
# 27   Drug or chemical induced diabetes mellitus wit...  2018-07-18
# 28   Drug or chemical induced diabetes mellitus wit...  2018-07-18
# 29   Drug or chemical induced diabetes mellitus wit...  2018-07-18
# ..                                                 ...         ...
# 183  Type 1 diabetes mellitus with unspecified diab...  2018-07-18
# 184  Type 1 diabetes mellitus with diabetic macular...  2018-07-18
# 185  Type 1 diabetes mellitus with diabetic macular...  2018-07-18
# 186  Type 1 diabetes mellitus with diabetic macular...  2018-07-18
# 187  Type 1 diabetes mellitus with diabetic macular...  2018-07-18
# 188  Central retinal vein occlusion left eye with r...  2018-07-18
# 189  Central retinal vein occlusion unspecified eye...  2018-07-18
# 190  Central retinal vein occlusion left eye with m...  2018-07-18
# 191  Central retinal vein occlusion right eye with ...  2018-07-18
# 192  Central retinal vein occlusion bilateral with ...  2018-07-18
# 193    Central retinal vein occlusion bilateral stable  2018-07-18
# 194  Central retinal vein occlusion bilateral with ...  2018-07-18
# 195     Central retinal vein occlusion left eye stable  2018-07-18
# 196  Central retinal vein occlusion unspecified eye...  2018-07-18
# 197  Central retinal vein occlusion right eye with ...  2018-07-18
# 198    Central retinal vein occlusion right eye stable  2018-07-18
# 199  Central retinal vein occlusion unspecified eye...  2018-07-18
# 200  Tributary (branch) retinal vein occlusion left...  2018-07-18
# 201  Tributary (branch) retinal vein occlusion unsp...  2018-07-18
# 202  Tributary (branch) retinal vein occlusion bila...  2018-07-18
# 203  Tributary (branch) retinal vein occlusion left...  2018-07-18
# 204  Tributary (branch) retinal vein occlusion righ...  2018-07-18
# 205  Tributary (branch) retinal vein occlusion righ...  2018-07-18
# 206  Tributary (branch) retinal vein occlusion righ...  2018-07-18
# 207  Tributary (branch) retinal vein occlusion unsp...  2018-07-18
# 208  Tributary (branch) retinal vein occlusion unsp...  2018-07-18
# 209  Tributary (branch) retinal vein occlusion bila...  2018-07-18
# 210  Tributary (branch) retinal vein occlusion bila...  2018-07-18
# 211  Tributary (branch) retinal vein occlusion left...  2018-07-18
# 212                 Venous engorgement unspecified eye  2018-07-18
#
#     active_reason deactive_date deactive_reason  \
# 0            Nish          None            None
# 1            Nish          None            None
# 2            Nish          None            None
# 3            Nish          None            None
# 4            Nish          None            None
# 5            Nish          None            None
# 6            Nish          None            None
# 7            Nish          None            None
# 8            Nish          None            None
# 9            Nish          None            None
# 10           Nish          None            None
# 11           Nish          None            None
# 12           Nish          None            None
# 13           Nish          None            None
# 14           Nish          None            None
# 15           Nish          None            None
# 16           Nish          None            None
# 17           Nish          None            None
# 18           Nish          None            None
# 19           Nish          None            None
# 20           Nish          None            None
# 21           Nish          None            None
# 22           Nish          None            None
# 23           Nish          None            None
# 24           Nish          None            None
# 25           Nish          None            None
# 26           Nish          None            None
# 27           Nish          None            None
# 28           Nish          None            None
# 29           Nish          None            None
# ..            ...           ...             ...
# 183          Nish          None            None
# 184          Nish          None            None
# 185          Nish          None            None
# 186          Nish          None            None
# 187          Nish          None            None
# 188          Nish          None            None
# 189          Nish          None            None
# 190          Nish          None            None
# 191          Nish          None            None
# 192          Nish          None            None
# 193          Nish          None            None
# 194          Nish          None            None
# 195          Nish          None            None
# 196          Nish          None            None
# 197          Nish          None            None
# 198          Nish          None            None
# 199          Nish          None            None
# 200          Nish          None            None
# 201          Nish          None            None
# 202          Nish          None            None
# 203          Nish          None            None
# 204          Nish          None            None
# 205          Nish          None            None
# 206          Nish          None            None
# 207          Nish          None            None
# 208          Nish          None            None
# 209          Nish          None            None
# 210          Nish          None            None
# 211          Nish          None            None
# 212          Nish          None            None
#
#                                        source
# 0    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 1    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 2    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 3    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 4    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 5    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 6    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 7    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 8    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 9    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 10   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 11   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 12   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 13   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 14   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 15   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 16   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 17   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 18   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 19   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 20   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 21   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 22   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 23   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 24   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 25   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 26   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 27   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 28   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 29   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# ..                                        ...
# 183  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 184  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 185  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 186  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 187  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 188  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 189  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 190  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 191  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 192  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 193  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 194  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 195  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 196  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 197  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 198  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 199  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 200  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 201  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 202  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 203  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 204  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 205  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 206  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 207  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 208  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 209  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 210  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 211  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 212  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
#
# [213 rows x 14 columns]

# %%
snow.select("select * from st_rvo_me_ref").to_excel("out/ref.xlsx", index=False)

# %% [markdown]
# # UPLOAD new ref table

# %%
df = pd.read_excel("out/ref.xlsx")

# %%
df
# Out:
#     cat1 cat2      cat3  cat4  cat5  cat6    type    value  \
# 0     dx   me  other_me   NaN   NaN   NaN  icd_10   E08311
# 1     dx   me  other_me   NaN   NaN   NaN  icd_10   E08321
# 2     dx   me  other_me   NaN   NaN   NaN  icd_10  E083211
# 3     dx   me  other_me   NaN   NaN   NaN  icd_10  E083212
# 4     dx   me  other_me   NaN   NaN   NaN  icd_10  E083213
# 5     dx   me  other_me   NaN   NaN   NaN  icd_10  E083219
# 6     dx   me  other_me   NaN   NaN   NaN  icd_10   E08331
# 7     dx   me  other_me   NaN   NaN   NaN  icd_10  E083311
# 8     dx   me  other_me   NaN   NaN   NaN  icd_10  E083312
# 9     dx   me  other_me   NaN   NaN   NaN  icd_10  E083313
# 10    dx   me  other_me   NaN   NaN   NaN  icd_10  E083319
# 11    dx   me  other_me   NaN   NaN   NaN  icd_10   E08341
# 12    dx   me  other_me   NaN   NaN   NaN  icd_10  E083411
# 13    dx   me  other_me   NaN   NaN   NaN  icd_10  E083412
# 14    dx   me  other_me   NaN   NaN   NaN  icd_10  E083413
# 15    dx   me  other_me   NaN   NaN   NaN  icd_10  E083419
# 16    dx   me  other_me   NaN   NaN   NaN  icd_10   E08351
# 17    dx   me  other_me   NaN   NaN   NaN  icd_10  E083511
# 18    dx   me  other_me   NaN   NaN   NaN  icd_10  E083512
# 19    dx   me  other_me   NaN   NaN   NaN  icd_10  E083513
# 20    dx   me  other_me   NaN   NaN   NaN  icd_10  E083519
# 21    dx   me  other_me   NaN   NaN   NaN  icd_10    E0837
# 22    dx   me  other_me   NaN   NaN   NaN  icd_10  E0837X1
# 23    dx   me  other_me   NaN   NaN   NaN  icd_10  E0837X2
# 24    dx   me  other_me   NaN   NaN   NaN  icd_10  E0837X3
# 25    dx   me  other_me   NaN   NaN   NaN  icd_10  E0837X9
# 26    dx   me  other_me   NaN   NaN   NaN  icd_10   E09311
# 27    dx   me  other_me   NaN   NaN   NaN  icd_10   E09321
# 28    dx   me  other_me   NaN   NaN   NaN  icd_10  E093211
# 29    dx   me  other_me   NaN   NaN   NaN  icd_10  E093212
# ..   ...  ...       ...   ...   ...   ...     ...      ...
# 183   dx   me  other_me   NaN   NaN   NaN   icd_9    25051
# 184   dx   me  other_me   NaN   NaN   NaN   icd_9    25051
# 185   dx   me  other_me   NaN   NaN   NaN   icd_9    25051
# 186   dx   me  other_me   NaN   NaN   NaN   icd_9    25051
# 187   dx   me  other_me   NaN   NaN   NaN   icd_9    25051
# 188   dx  rvo      crvo   NaN   NaN   NaN   icd_9    36235
#
Tributary (branch) retinal vein occlusion left...  2018-07-18
# 212                 Venous engorgement unspecified eye  2018-07-18
#
#     active_reason  deactive_date  deactive_reason  \
# 0            Nish            NaN              NaN
# 1            Nish            NaN              NaN
# 2            Nish            NaN              NaN
# 3            Nish            NaN              NaN
# 4            Nish            NaN              NaN
# 5            Nish            NaN              NaN
# 6            Nish            NaN              NaN
# 7            Nish            NaN              NaN
# 8            Nish            NaN              NaN
# 9            Nish            NaN              NaN
# 10           Nish            NaN              NaN
# 11           Nish            NaN              NaN
# 12           Nish            NaN              NaN
# 13           Nish            NaN              NaN
# 14           Nish            NaN              NaN
# 15           Nish            NaN              NaN
# 16           Nish            NaN              NaN
# 17           Nish            NaN              NaN
# 18           Nish            NaN              NaN
# 19           Nish            NaN              NaN
# 20           Nish            NaN              NaN
# 21           Nish            NaN              NaN
# 22           Nish            NaN              NaN
# 23           Nish            NaN              NaN
# 24           Nish            NaN              NaN
# 25           Nish            NaN              NaN
# 26           Nish            NaN              NaN
# 27           Nish            NaN              NaN
# 28           Nish            NaN              NaN
# 29           Nish            NaN              NaN
# ..            ...            ...              ...
# 183          Nish            NaN              NaN
# 184          Nish            NaN              NaN
# 185          Nish            NaN              NaN
# 186          Nish            NaN              NaN
# 187          Nish            NaN              NaN
# 188          Nish            NaN              NaN
# 189          Nish            NaN              NaN
# 190          Nish            NaN              NaN
# 191          Nish            NaN              NaN
# 192          Nish            NaN              NaN
# 193          Nish            NaN              NaN
# 194          Nish            NaN              NaN
# 195          Nish            NaN              NaN
# 196          Nish            NaN              NaN
# 197          Nish            NaN              NaN
# 198          Nish            NaN              NaN
# 199          Nish            NaN              NaN
# 200          Nish            NaN              NaN
# 201          Nish            NaN              NaN
# 202          Nish            NaN              NaN
# 203          Nish            NaN              NaN
# 204          Nish            NaN              NaN
# 205          Nish            NaN              NaN
# 206          Nish            NaN              NaN
# 207          Nish            NaN              NaN
# 208          Nish            NaN              NaN
# 209          Nish            NaN              NaN
# 210          Nish            NaN              NaN
# 211          Nish            NaN              NaN
# 212          Nish            NaN              NaN
#
#                                        source
# 0    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 1    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 2    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 3    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 4    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 5    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 6    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 7    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 8    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 9    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 10   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 11   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 12   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 13   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 14   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 15   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 16   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 17   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 18   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 19   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 20   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 21   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 22   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 23   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 24   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 25   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 26   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 27   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 28   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 29   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# ..                                        ...
# 183  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 184  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 185  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 186  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 187  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 188  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 189  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 190  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 191  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 192  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 193  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 194  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 195  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 196  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 197  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 198  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 199  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 200  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 201  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 202  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 203  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 204  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 205  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 206  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 207  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 208  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 209  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 210  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 211  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 212  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
#
# [213 rows x 14 columns]

# %%
snow.drop_table("st_rvo_me_ref")
# Out:
# DROP TABLE IF EXISTS sandbox_analytics.sandbox.st_rvo_me_ref;
# Table sandbox.st_rvo_me_ref dropped!

# %%
snow.upload_dataframe(df, "st_rvo_me_ref")
# Out:
# Upload successful!

# %%
# %%read_sql
#
# select * from st_rvo_me_ref
# Out:
# Query started at 11:26:24 AM GMT Daylight Time; Query executed in 0.07 m
#     cat1 cat2      cat3  cat4  cat5  cat6    type    value  \
# 0     dx   me  other_me  None  None  None  icd_10   E08311
# 1     dx   me  other_me  None  None  None  icd_10   E08321
Tributary (branch) retinal vein occlusion bila...  2018-07-18
# 210  Tributary (branch) retinal vein occlusion bila...  2018-07-18
# 211  Tributary (branch) retinal vein occlusion left...  2018-07-18
# 212                 Venous engorgement unspecified eye  2018-07-18
#
#     active_reason deactive_date deactive_reason  \
# 0            Nish          None            None
# 1            Nish          None            None
# 2            Nish          None            None
# 3            Nish          None            None
# 4            Nish          None            None
# 5            Nish          None            None
# 6            Nish          None            None
# 7            Nish          None            None
# 8            Nish          None            None
# 9            Nish          None            None
# 10           Nish          None            None
# 11           Nish          None            None
# 12           Nish          None            None
# 13           Nish          None            None
# 14           Nish          None            None
# 15           Nish          None            None
# 16           Nish          None            None
# 17           Nish          None            None
# 18           Nish          None            None
# 19           Nish          None            None
# 20           Nish          None            None
# 21           Nish          None            None
# 22           Nish          None            None
# 23           Nish          None            None
# 24           Nish          None            None
# 25           Nish          None            None
# 26           Nish          None            None
# 27           Nish          None            None
# 28           Nish          None            None
# 29           Nish          None            None
# ..            ...           ...             ...
# 183          Nish          None            None
# 184          Nish          None            None
# 185          Nish          None            None
# 186          Nish          None            None
# 187          Nish          None            None
# 188          Nish          None            None
# 189          Nish          None            None
# 190          Nish          None            None
# 191          Nish          None            None
# 192          Nish          None            None
# 193          Nish          None            None
# 194          Nish          None            None
# 195          Nish          None            None
# 196          Nish          None            None
# 197          Nish          None            None
# 198          Nish          None            None
# 199          Nish          None            None
# 200          Nish          None            None
# 201          Nish          None            None
# 202          Nish          None            None
# 203          Nish          None            None
# 204          Nish          None            None
# 205          Nish          None            None
# 206          Nish          None            None
# 207          Nish          None            None
# 208          Nish          None            None
# 209          Nish          None            None
# 210          Nish          None            None
# 211          Nish          None            None
# 212          Nish          None            None
#
#                                        source
# 0    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 1    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 2    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 3    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 4    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 5    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 6    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 7    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 8    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 9    RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 10   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 11   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 12   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 13   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 14   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 15   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 16   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 17   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 18   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 19   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 20   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 21   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 22   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 23   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 24   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 25   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 26   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 27   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 28   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 29   RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# ..                                        ...
# 183  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 184  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 185  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 186  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 187  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 188  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 189  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 190  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 191  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 192  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 193  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 194  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 195  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 196  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 197  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 198  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 199  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 200  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 201  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 202  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 203  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 204  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 205  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 206  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 207  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 208  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 209  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 210  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 211  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
# 212  RWD_DB.RWD_REFERENCE_LIBRARY.ICD_GROUPER
#
# [213 rows x 14 columns]

# %% [markdown]
# # Analysis plan

# %% [markdown]
# <img src="in/cohort.png", width=700>

# %% [markdown]
# # Cohort in obs. window
#
# <img src="in/cohort.png", width=700>

# %%
# %%read_sql
#
# create or replace table st_rvo_obs_cohort as
#
# select
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,
#     claim_number,
#     diagnosis,
#     diagnosis_sequence,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS
# where
#     diagnosis in (select distinct value from st_rvo_me_ref where cat2 = 'rvo' and deactive_date is null)
#     and year_of_service between '2016-01-01' and '2017-12-31'
# Out:
# Query started at 04:29:06 PM India Standard TimeInitiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ; Query executed in 11.96 m
#                                           status
# 0  Table ST_RVO_OBS_COHORT successfully created.

# %%
snow.select("select count(distinct patient_id) from st_rvo_obs_cohort where left(patient_id, 5) != 'XXX -'")
# Out:
#    COUNT(DISTINCT PATIENT_ID)
# 0                      220932

# %% [markdown]
# ## Index date

# %%
# %%read_sql
#
# create or replace table st_rvo_index as
#
# select
#     patient_id,
#     min(year_of_service) as index_date
# from
#     st_rvo_obs_cohort
# where
#     left(patient_id, 5) != 'XXX -'
# group by 1
# Out:
# Query started at 04:44:28 PM India Standard Time; Query executed in 0.14 m
#                                      status
# 0  Table ST_RVO_INDEX successfully created.

# %%
snow.select("select * from st_rvo_index order by index_date desc limit 5")
# Out:
#          patient_id  index_date
# 0  qSO4bEA0RrOyEsnW  2017-12-31
# 1  P0Zgm1bdgm7TEi4/  2017-12-31
# 2  MQuzWQejJ15nq4eX  2017-12-31
# 3  il58OmHZqrsUyjcc  2017-12-30
# 4  m4783E4g8p5dFsQ3  2017-12-30

# %%
snow.select("select count(patient_id) from st_rvo_index where left(patient_id, 5) = 'XXX -'")
# Out:
#    COUNT(PATIENT_ID)
# 0                  0

# %% [markdown]
# # Continuous coverage

# %% [markdown]
# ## Cont. cov from medical claims
# <img src="in/cohort1.png">

# %% [markdown]
# ### Extract submits header

# %%
# %%read_sql
#
# create or replace table st_rvo_cont_med as
#
# select
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,
#     claim_number,
#     claim_type_code,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_HEADER
# where
#     left(encrypted_key_1, 8)||left(encrypted_key_2, 8) in (select patient_id from st_rvo_index)
#     and year_of_service between '2015-07-01' and '2018-06-30'
# Out:
# Query started at 04:44:57 PM India Standard Time; Query executed in 5.64 m
#                                         status
# 0  Table ST_RVO_CONT_MED successfully created.

# %% [markdown]
# ### Check for duplicates

# %%
# %%read_sql
#
# select count(*) from st_rvo_cont_med
# Out:
# Query started at 04:55:32 PM India Standard Time; Query executed in 0.06 m
#    COUNT(*)
# 0  12050552

# %%
# %%read_sql
#
# with t1 as (select distinct * from st_rvo_cont_med)
# select count(*) from t1
# Out:
# Query started at 04:55:38 PM India Standard Time; Query executed in 0.11 m
#    COUNT(*)
# 0  11930226

# %%
# %%read_sql
#
# drop table if exists st_rvo_cont_med_unique;
# create or replace table st_rvo_cont_med_unique as
# select distinct * from st_rvo_cont_med;
# drop table st_rvo_cont_med;
# Out:
# Query started at 04:55:47 PM India Standard Time; Query executed in 0.06 mQuery started at 04:55:51 PM India Standard Time; Query executed in 0.11 mQuery started at 04:55:57 PM India Standard Time; Query executed in 0.04 m
#                                   status
# 0  ST_RVO_CONT_MED successfully dropped.

# %% [markdown]
# ### Summarise medical claims

# %%
# %%read_sql
#
# create or replace table st_rvo_cont_med_tally as
#
# select
#     a.patient_id,
#     sum(case
#            when datediff(d, a.index_date, b.year_of_service) between -182 and -1
#            then 1
#            else 0
#            end) as claim_tally_pre,
#     sum(case
#            when datediff(d, a.index_date, b.year_of_service) between 1 and 182
#            then 1
#            else 0
#            end) as claim_tally_post
# from
#     st_rvo_index a
#         join st_rvo_cont_med_unique b
#             on a.patient_id = b.patient_id
# group by 1
# Out:
# Query started at 04:56:13 PM India Standard Time; Query executed in 0.09 m
#                                               status
# 0  Table ST_RVO_CONT_MED_TALLY successfully created.

# %% [markdown]
# ### Final counts

# %%
a = snow.select("select count(distinct patient_id) from st_rvo_cont_med_tally")
b = snow.select("select count(distinct patient_id) from st_rvo_cont_med_tally where claim_tally_pre > 0 and claim_tally_post > 0")
c = snow.select("select count(distinct patient_id) from st_rvo_cont_med_tally where claim_tally_pre > 1 and claim_tally_post > 1")
d = snow.select("select count(distinct patient_id) from st_rvo_cont_med_tally where claim_tally_pre > 2 and claim_tally_post > 2")
e = snow.select("select count(distinct patient_id) from st_rvo_cont_med_tally where claim_tally_pre > 3 and claim_tally_post > 3")
f = snow.select("select count(distinct patient_id) from st_rvo_cont_med_tally where claim_tally_pre > 4 and claim_tally_post > 4")

lst = ['pts_obs_window',
       '1_claim_pre_and_post',
       '2_claims_pre_and_post',
       '3_claims_pre_and_post',
       '4_claims_pre_and_post',
       '5_claims_pre_and_post',]

pd.concat([a,b,c,d,e,f], keys=lst)
# Out:
#                          COUNT(DISTINCT PATIENT_ID)
# pts_obs_window        0                      220932
# 1_claim_pre_and_post  0                      169735
# 2_claims_pre_and_post 0                      143156
# 3_claims_pre_and_post 0                      121172
# 4_claims_pre_and_post 0                      103314
# 5_claims_pre_and_post 0                       88232

# %% [markdown]
# ## Final cohort

# %%
# %%read_sql
#
# create or replace table st_rvo_cohort as
#
# select
#     patient_id,
#     index_date
# from
#     st_rvo_index
# where
#     patient_id in (select patient_id
#                    from st_rvo_cont_med_tally
#                    where claim_tally_pre > 1
#                    and claim_tally_post > 1)
# Out:
# Query started at 04:57:12 PM India Standard Time; Query executed in 0.09 m
#                                       status
# 0  Table ST_RVO_COHORT successfully created.

# %%
snow.select("select count(distinct patient_id) from st_rvo_cohort")
# Out:
#    COUNT(DISTINCT PATIENT_ID)
# 0                      143156

# %% [markdown]
# # Raw data extracts

# %% [markdown]
# Pull all diagnoses data for the cohort of patients from July 1st 2015, to June 30th 2018
# <img src="in/cohort.png", width=700>

# %% [markdown]
# ## Claim header

# %%
# %%read_sql
#
# create or replace table st_rvo_header_all as
#
# select
#      'XXXXXXXXXXXXXXXX' as patient_id,
#      claim_number,
#      received_date,
#      claim_type_code,
#      statement_from,
#      statement_to,
#      min_service_from,
#      max_service_to,
#      total_charge,
#      total_allowed,
#      drg_code,
#      type_bill,
#      admission_date,
#      admit_type_code,
#      admit_src_code,
#      discharge_hour,
#      discharge_status,
#      new_medicare_source,
#      year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_HEADER
# where
#      claim_number in (select distinct claim_number
#                       from st_rvo_cont_med_unique
#                       where patient_id in (select patient_id
#                                            from st_rvo_cohort))
# Out:
# Query started at 04:57:49 PM India Standard Time; Query executed in 3.39 m
#                                           status
# 0  Table ST_RVO_HEADER_ALL successfully created.

# %%
# %%read_sql
#
#  begin;
#  update st_rvo_header_all a
#     set a.patient_id = b.patient_id
#    from st_rvo_cont_med_unique b
#   where a.claim_number = b.claim_number;
# commit;
# Out:
# Query started at 05:44:58 PM India Standard Time; Query executed in 0.07 mQuery started at 05:45:03 PM India Standard Time; Query executed in 0.19 mQuery started at 05:45:14 PM India Standard Time; Query executed in 0.03 m
#                              status
# 0  Statement executed successfully.

# %%
# %%read_sql
#
# select
#     count(patient_id),
#     count(distinct patient_id),
#     sum(case
#            when patient_id = 'XXXXXXXXXXXXXXXX'
#            then 1
#            else 0
#            end) as null_pt_id,
#     sum(case
#            when left(patient_id, 5) = 'XXX -'
#            then 1
#            else 0
#            end) as faulty_pt_id
# from st_rvo_header_all
# Out:
# Query started at 05:45:16 PM India Standard Time; Query executed in 0.06 m
#    COUNT(PATIENT_ID)  COUNT(DISTINCT PATIENT_ID)  null_pt_id  faulty_pt_id
# 0           10636099                      143156           0             0

# %% [markdown]
# ## Diagnoses

# %%
# %%read_sql
#
# create or replace table st_rvo_dx_all as
#
# select
#     'XXXXXXXXXXXXXXXX' as patient_id,
#     claim_number,
#     diagnosis,
#     diagnosis_sequence,
#     statement_from,
#     statement_to,
#     min_service_from,
#     max_service_to,
#     received_date,
#     year_of_service
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS
# where
#     claim_number in (select distinct claim_number
#                      from st_rvo_header_all)
# Out:
# Query started at 05:45:34 PM India Standard Time; Query executed in 5.06 m
#                                       status
# 0  Table ST_RVO_DX_ALL successfully created.

# %%
# %%read_sql
#
# begin;
# update st_rvo_dx_all a
# set a.patient_id = b.patient_id
# from st_rvo_header_all b
# where a.claim_number = b.claim_number
# Out:
# Query started at 05:50:38 PM India Standard Time; Query executed in 0.04 mQuery started at 05:50:40 PM India Standard Time; Query executed in 0.23 m
#    number of rows updated  number of multi-joined rows updated
# 0                36284008                               884082

# %%
# %%read_sql
#
# select
#     count(patient_id),
#     count(distinct patient_id),
#     sum(case
#            when patient_id = 'XXXXXXXXXXXXXXXX'
#            then 1
#            else 0
#            end) as null_pt_id,
#     sum(case
#            when left(patient_id, 5) = 'XXX -'
#            then 1
#            else 0
#            end) as faulty_pt_id
#
# from st_rvo_dx_all
# Out:
# Query started at 05:50:54 PM India Standard Time; Query executed in 0.07 m
#    COUNT(PATIENT_ID)  COUNT(DISTINCT PATIENT_ID)  null_pt_id  faulty_pt_id
# 0           36284008                      143156           0             0

# %% [markdown]
# ## Patient raw

# %%
# %%read_sql
#
# create or replace table st_rvo_pat_all as
#
# select
#     'XXXXXXXXXXXXXXXX' as patient_id,
#     claim_number,
#     patient_gender,
#     patient_dob
# from
#     RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_PATIENT
# where
#     claim_number in (select distinct claim_number
#                      from st_rvo_header_all)
# Out:
# Query started at 05:50:58 PM India Standard Time; Query executed in 3.94 m
#                                        status
# 0  Table ST_RVO_PAT_ALL successfully created.

# %%
# %%read_sql
#
#  begin;
#  update st_rvo_pat_all a
#     set a.patient_id = b.patient_id
#    from st_rvo_header_all b
#   where a.claim_number = b.claim_number;
# commit;
# Out:
# Query started at 05:54:55 PM India Standard Time; Query executed in 0.03 mQuery started at 05:54:57 PM India Standard Time; Query executed in 0.28 mQuery started at 05:55:14 PM India Standard Time; Query executed in 0.05 m
#                              status
# 0  Statement executed successfully.

# %%
# %%read_sql
#
# create or replace table st_rvo_pat_all_unique as
#
# select
#     patient_id,
#     min(patient_dob) as dob,
#     min(patient_gender) as gender
# from
#     st_rvo_pat_all
# group by 1
# Out:
# Query started at 05:55:16 PM India Standard Time; Query executed in 0.10 m
#                                               status
# 0  Table ST_RVO_PAT_ALL_UNIQUE successfully created.

# %%
# %%read_sql
#
# select
#     count(patient_id),
#     count(distinct patient_id),
#     sum(case
#            when patient_id = 'XXXXXXXXXXXXXXXX'
#            then 1
#            else 0
#            end) as null_pt_id,
#     sum(case
#            when left(patient_id, 5) = 'XXX -'
#            then 1
#            else 0
#            end) as faulty_pt_id
#
# from st_rvo_pat_all_unique
# Out:
# Query started at 05:55:23 PM India Standard Time; Query executed in 0.07 m
#    COUNT(PATIENT_ID)  COUNT(DISTINCT PATIENT_ID)  null_pt_id  faulty_pt_id
# 0             143156                      143156           0             0

# %% [markdown]
# # Master table

# %% [markdown]
# ## Aggregate comorbidity Dx

# %%
snow.select("select distinct cat3, cat2 from st_rvo_me_ref")
# Out:
#        cat3 cat2
# 0  other_me   me
# 1      crvo  rvo
# 2        ve  rvo
# 3      brvo  rvo

# %%
# %%read_sql
#
# create or replace table st_rvo_comorbidites_agg as
#
# select
#     a.patient_id,
#     1 as rvo,
#     max(case
#            when b.diagnosis in (select distinct value
#                                 from st_rvo_me_ref
#                                 where cat2 = 'me'
#                                 and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -182 and 182
#            then 1
#            else 0
#            end) as me,
#     max(case
#            when b.diagnosis in (select distinct value
#                                 from st_rvo_me_ref
#                                 where cat3 = 'crvo'
#                                 and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -182 and 182
#            then 1
#            else 0
#            end) as crvo,
#     max(case
#            when b.diagnosis in (select distinct value
#                                 from st_rvo_me_ref
#                                 where cat3 = 'brvo'
#                                 and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -182 and 182
#            then 1
#            else 0
#            end) as brvo,
#     max(case
#            when b.diagnosis in (select distinct value
#                                 from st_rvo_me_ref
#                                 where cat3 = 've'
#                                 and deactive_date is null)
#            and datediff(d, a.index_date, b.year_of_service) between -182 and 182
#            then 1
#            else 0
#            end) as ve
# from
#     st_rvo_cohort a
#         join st_rvo_dx_all b
#             on a.patient_id = b.patient_id
# group by 1
# Out:
# Query started at 06:12:02 PM India Standard Time; Query executed in 0.35 m
#                                               status
# 0  Table ST_RVO_COMORBIDITES_AGG successfully cre...

# %%
snow.select("select * from st_rvo_comorbidites_agg limit").to_excel("out/results.xlsx", index=False)

# %% [markdown]
# ## Patient age

# %%
# %%read_sql
#
# create or replace table st_rvo_patient_demographics as
#
# select
#     a.patient_id,
#     b.gender,
#     datediff(yy, b.dob, a.index_date) as age,
#     case
#         when datediff(yy, b.dob, a.index_date) between 0 and 4 then '00-04'
#         when datediff(yy, b.dob, a.index_date) between 5 and 9 then '05-09'
#         when datediff(yy, b.dob, a.index_date) between 10 and 14 then '10-14'
#         when datediff(yy, b.dob, a.index_date) between 15 and 19 then '15-19'
#         when datediff(yy, b.dob, a.index_date) between 20 and 24 then '20-24'
#         when datediff(yy, b.dob, a.index_date) between 25 and 29 then '25-29'
#         when datediff(yy, b.dob, a.index_date) between 30 and 34 then '30-34'
#         when datediff(yy, b.dob, a.index_date) between 35 and 39 then '35-39'
#         when datediff(yy, b.dob, a.index_date) between 40 and 44 then '40-44'
#         when datediff(yy, b.dob, a.index_date) between 45 and 49 then '45-49'
#         when datediff(yy, b.dob, a.index_date) between 50 and 54 then '50-54'
#         when datediff(yy, b.dob, a.index_date) between 55 and 59 then '55-59'
#         when datediff(yy, b.dob, a.index_date) between 60 and 64 then '60-64'
#         when datediff(yy, b.dob, a.index_date) between 65 and 69 then '65-69'
#         when datediff(yy, b.dob, a.index_date) between 70 and 74 then '70-74'
#         when datediff(yy, b.dob, a.index_date) between 75 and 79 then '75-79'
#         when datediff(yy, b.dob, a.index_date) between 80 and 84 then '80-84'
#         when datediff(yy, b.dob, a.index_date) between 85 and 110 then '85+'
#         else null
#         end as age_cat
# from
#     st_rvo_cohort a
#         join st_rvo_pat_all_unique b
#             on a.patient_id = b.patient_id
# Out:
# Query started at 06:15:34 PM India Standard Time; Query executed in 0.12 m
#                                               status
# 0  Table ST_RVO_PATIENT_DEMOGRAPHICS successfully...

# %% [markdown]
# ## Master table

# %%
snow.drop_table("st_rvo_master_table")

# %%
# %%read_sql
#
# create or replace table st_rvo_master_table as
#
# select
#     a.patient_id,
#     null as wt,
#     a.gender,
#     a.age,
#     a.age_cat,
#     b.rvo,
#     b.me,
#     b.crvo,
#     b.brvo,
#     b.ve
# from
#     st_rvo_patient_demographics a
#         join st_rvo_comorbidites_agg b
#             on a.patient_id = b.patient_id
# Out:
# Query started at 06:16:29 PM India Standard Time; Query executed in 0.18 m
#                                             status
# 0  Table ST_RVO_MASTER_TABLE successfully created.

# %%
snow.select("select * from st_rvo_master_table limit 50")
# Out:
#           patient_id    wt gender  age age_cat  rvo  me  crvo  brvo  ve
# 0   cfobAq2DguhAozRM  None      M   77   75-79    1   0     0     1   0
# 1   J44mz8vzeaBaV3Nz  None      F   84   80-84    1   0     0     1   0
# 2   wkr9O1LCAEhYl/d7  None      F   76   75-79    1   0     0     1   0
# 3   g3++qgyBran+DIAU  None      M   83   80-84    1   1     0     1   0
# 4   +BSz5zNV/vaeuf0B  None      F   79   75-79    1   0     0     1   0
# 5   tUxXdzEUAaE1lzON  None      M   74   70-74    1   0     0     1   0
# 6   OoSFLQ1LmmVpgEYI  None      F   74   70-74    1   1     0     1   0
# 7   fHETtVMmoPWNdWG2  None      M   74   70-74    1   0     0     1   0
# 8   2pBko/V4W8UPLL99  None      F   68   65-69    1   0     0     1   0
# 9   NEfe5qgQvCF9ssjT  None      M   74   70-74    1   0     0     1   0
# 10  /LrBdH45r21mtmwM  None      M   71   70-74    1   0     0     1   0
# 11  6OQWi6SG4n90HflZ  None      M   87     85+    1   0     1     1   0
# 12  +oryIKSDf3rh6CtT  None      F   87     85+    1   0     0     1   0
# 13  3LG3J1RIIS3Fm66h  None      F   88     85+    1   0     0     1   0
# 14  ZvP8YjomXzr2nZxt  None      F   90     85+    1   0     0     1   0
# 15  KtsNGc8m/mi7NBls  None      M   90     85+    1   0     0     1   0
# 16  a7+iCDM6h3m+d/0t  None      F   91     85+    1   0     0     1   0
# 17  3LdMswtmDr+t9/I3  None      M   89     85+    1   1     0     1   0
# 18  6JmX4aeXuTsfeEP5  None      M   91     85+    1   0     0     1   0
# 19  ctL+0XOTj2dw9Y2+  None      F   89     85+    1   0     0     1   0
# 20  jL9LllW4+2N56qVj  None      M   84   80-84    1   0     0     1   0
# 21  x+03id6uQjODbx8B  None      M   76   75-79    1   0     1     1   0
# 22  r3XO3WbdPfh6oQcY  None      F   78   75-79    1   0     0     1   0
# 23  MHpD8MtFo6saPImE  None      F   78   75-79    1   1     0     1   0
# 24  MRurOY1w9jRuNefu  None      M   84   80-84    1   0     0     1   0
# 25  2LgS0FHzYRzVQRQg  None      F   90     85+    1   1     0     1   0
# 26  ImMwj1Sw5AGijQt9  None      M   75   75-79    1   0     0     1   0
# 27  97TWIgH8/MiOjj8J  None      M   68   65-69    1   0     1     1   0
# 28  Ei1gwNJrnjxMd9zj  None      F   80   80-84    1   0     0     1   0
# 29  fcvg6VV2Vy5D6eWn  None      F   78   75-79    1   0     0     1   0
# 30  mzqik/OzbqYVq01X  None      F   77   75-79    1   0     0     1   0
# 31  BWypd78Iuczk1VKg  None      F   80   80-84    1   1     0     1   0
# 32  euI+F0iTkYosG/Tx  None      M   78   75-79    1   0     0     1   0
# 33  Lm1iXBYYJsCWzp+q  None      M   47   45-49    1   0     0     1   0
# 34  eoquq/AVoMGcOZzV  None      M   77   75-79    1   0     0     1   0
# 35  qeWkFyywKdcWzQbs  None      F   82   80-84    1   0     0     1   0
# 36  Er+7o3B0G3BfWCr4  None      F   87     85+    1   0     0     1   0
# 37  QYlT4tvPN+3srqtD  None      F   86     85+    1   0     0     1   0
# 38  LRLNpPv6KvOiVnjB  None      F   89     85+    1   0     1     1   0
# 39  W/AsPsSNAxrdPlij  None      M   91     85+    1   0     1     1   0
# 40  J4kitkl3s9DQksh5  None      F   89     85+    1   0     0     1   0
# 41  zjw6QOKrfUog/9KW  None      F   79   75-79    1   0     0     1   0
# 42  7fR84M4jg9lX8CP0  None      F   78   75-79    1   0     0     1   0
# 43  egv8S4T09YF+B0E1  None      F   77   75-79    1   0     0     1   0
# 44  9u1ciMe5HbUs6PcU  None      M   77   75-79    1   0     0     1   0
# 45  +NBxKbHLnnAmqK+9  None      M   72   70-74    1   0     0     1   0
# 46  jhAUOYl/ILUhom2x  None      F   74   70-74    1   0     0     1   0
# 47  728OfEj1mekISLWJ  None      M   80   80-84    1   0     0     1   0
# 48  Lnne0dcwIJNnRaqR  None      F   83   80-84    1   0     0     1   0
# 49  anH3pGRnX8h+GR/W  None      F   85     85+    1   0     0     1   0

# %% [markdown]
# # Summary results

# %%
# %%read_sql
#
# select
#     --age_cat,
#     sum(rvo) as rvo_pts,
#     sum(me) as me_pts,
#     round(sum(me)/sum(rvo)*100, 2) as me_in_rvo,
#     sum(crvo) as crvo_pts,
#     round(sum(crvo)/sum(rvo)*100, 2) as crvo_in_rvo,
#     sum(brvo) as brvo_pts,
#     round(sum(brvo)/sum(rvo)*100, 2) as brvo_in_rvo,
#     sum(ve) as ve_pts,
#     round(sum(ve)/sum(rvo)*100, 2) as ve_in_rvo
# from
#     st_rvo_master_table
# --group by 1
# --order by 1
# Out:
# Query started at 06:17:32 PM India Standard Time; Query executed in 0.06 m
#    rvo_pts  me_pts  me_in_rvo  crvo_pts  crvo_in_rvo  brvo_pts  brvo_in_rvo  \
# 0   143156   12007       8.39     63229        44.17     87165        60.89
#
#    ve_pts  ve_in_rvo
# 0    1975       1.38

# %%
# %%read_sql
#
# select
#     age_cat,
#     sum(rvo) as rvo_pts,
#     sum(me) as me_pts,
#     round(sum(me)/sum(rvo)*100, 2) as me_in_rvo,
#     sum(crvo) as crvo_pts,
#     round(sum(crvo)/sum(rvo)*100, 2) as crvo_in_rvo,
#     sum(brvo) as brvo_pts,
#     round(sum(brvo)/sum(rvo)*100, 2) as brvo_in_rvo,
#     sum(ve) as ve_pts,
#     round(sum(ve)/sum(rvo)*100, 2) as ve_in_rvo
# from
#     st_rvo_master_table
# group by 1
# order by 1
# Out:
# Query started at 06:18:04 PM India Standard Time; Query executed in 0.04 m
#    age_cat  rvo_pts  me_pts  me_in_rvo  crvo_pts  crvo_in_rvo  brvo_pts  \
# 0    00-04       10       0       0.00         7        70.00         1
# 1    05-09       16       1       6.25         8        50.00         4
# 2    10-14       31       0       0.00        12        38.71         4
# 3    15-19       71       4       5.63        33        46.48        13
# 4    20-24      112       3       2.68        77        68.75        30
# 5    25-29      217      24      11.06       154        70.97        58
# 6    30-34      363      39      10.74       249        68.60       121
# 7    35-39      582      75      12.89       339        58.25       258
# 8    40-44      964     121      12.55       522        54.15       490
# 9    45-49     1977     269      13.61       920        46.54      1122
# 10   50-54     3806     509      13.37      1707        44.85      2266
# 11   55-59     7014     871      12.42      3059        43.61      4275
# 12   60-64    11129    1311      11.78      4742        42.61      6932
# 13   65-69    18369    1936      10.54      7767        42.28     11492
# 14   70-74    22842    2138       9.36      9567        41.88     14422
# 15   75-79    23862    1884       7.90     10278        43.07     14853
# 16   80-84    21994    1463       6.65      9847        44.77     13327
# 17     85+    29789    1359       4.56     13938        46.79     17492
# 18    None        8       0       0.00         3        37.50         5
#
#     brvo_in_rvo  ve_pts  ve_in_rvo
# 0         10.00       2      20.00
# 1         25.00       4      25.00
# 2         12.90      15      48.39
# 3         18.31      29      40.85
# 4         26.79      14      12.50
# 5         26.73      16       7.37
# 6         33.33      21       5.79
# 7         44.33      29       4.98
# 8         50.83      29       3.01
# 9         56.75      58       2.93
# 10        59.54      89       2.34
# 11        60.95     134       1.91
# 12        62.29     180       1.62
# 13        62.56     267       1.45
# 14        63.14     308       1.35
# 15        62.25     282       1.18
# 16        60.59     254       1.15
# 17        58.72     244       0.82
# 18        62.50       0       0.00

# %%
snow.select("select * from st_rvo_master_table").to_excel("out/final_results.xlsx", index=False)
