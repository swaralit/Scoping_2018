# %% [markdown]
# # Objective
# Client requirements:
# 1. Growth hormone-related disorders
# 2. Growth hormone - US only
# 3. Hypoparathyroidism - US and Europe
# 4. Metrics:
#     Market share(value and volume), by brand and by indication, currently and historical trends.
#     Data on the payer landscape/contracts by brand and by indication would also be very helpful.
#     For HP, TRx and NRx trends would be helpful.

# %% [markdown]
# ## Analysis plan
# Look into Albatross, Pelican and Raven

# %% [markdown]
# # Initialization steps

# %% [markdown]
# ## Importing relevant modules

# %%
import pandas as pd
from drg_connect import Snowflake
import qgrid 
from datetime import timedelta, datetime
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Connecting to snowflake

# %%
##defining parameters of snowflake
snow = Snowflake(role = 'RWD_ANALYTICS_RW',database='SANDBOX_ANALYTICS',schema = 'SANDBOX')
engine = snow.engine

# %reload_ext sql_magic
# %config SQL.output_result = True  #Enable output to std out
# %config SQL.notify_result = False #disable browser notifications
# %config SQL.conn_name = 'engine'  #Set the sql_magic connection engine

# %% [markdown]
# # Reference tables
# For relevant ICD codes, number of EHR records and number of claims

# %% [markdown]
# ## ICD grouper table

# %%
snow.select("select * from RWD_DB.RWD.ICD_GROUPER limit 3")
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
#    id     level_1                        level_1_description  level_2  \
# 0   1  A00 - B999  Certain infectious and parasitic diseases  A00-A09
# 1   2  A00 - B999  Certain infectious and parasitic diseases  A00-A09
# 2   3  A00 - B999  Certain infectious and parasitic diseases  A00-A09
#
#               level_2_description   level_3 level_3_description level_4  \
# 0  Intestinal infectious diseases  A00-A009             Cholera     A00
# 1  Intestinal infectious diseases  A00-A009             Cholera    A000
# 2  Intestinal infectious diseases  A00-A009             Cholera    A001
#
#   icd9_mapped_codes                       icd9_description  \
# 0            No map                                 No map
# 1              0010         Cholera due to vibrio cholerae
# 2              0011  Cholera due to vibrio cholerae el tor
#
#                      level_4_short_description_icd10  \
# 0                                            Cholera
# 1  Cholera due to Vibrio cholerae 01 biovar cholerae
# 2     Cholera due to Vibrio cholerae 01 biovar eltor
#
#                       level_4_long_description_icd10   create_ts   update_ts
# 0                                            Cholera  2017-11-02  2017-11-02
# 1  Cholera due to Vibrio cholerae 01 biovar cholerae  2017-11-02  2017-11-02
# 2     Cholera due to Vibrio cholerae 01 biovar eltor  2017-11-02  2017-11-02

# %%
# %%read_sql
#
# select
#     *
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     level_4_short_description_icd10 ilike '%hypoparathyroidism%'
# Out:
# Query started at 01:24:33 PM India Standard Time; Query executed in 0.06 m
#       id       level_1                                level_1_description  \
# 0   4300  E00 -  E8989       Endocrine nutritional and metabolic diseases
# 1   4301  E00 -  E8989       Endocrine nutritional and metabolic diseases
# 2   4302  E00 -  E8989       Endocrine nutritional and metabolic diseases
# 3   4303  E00 -  E8989       Endocrine nutritional and metabolic diseases
# 4   4304  E00 -  E8989       Endocrine nutritional and metabolic diseases
# 5   4811  E00 -  E8989       Endocrine nutritional and metabolic diseases
# 6  27440    P00 - P969  Certain conditions originating in the perinata...
#
#    level_2                                level_2_description   level_3  \
# 0  E20-E35                Disorders of other endocrine glands  E20-E209
# 1  E20-E35                Disorders of other endocrine glands  E20-E209
# 2  E20-E35                Disorders of other endocrine glands  E20-E209
# 3  E20-E35                Disorders of other endocrine glands  E20-E209
# 4  E20-E35                Disorders of other endocrine glands  E20-E209
# 5  E89-E89  Postprocedural endocrine and metabolic complic...  E89-E898
# 6  P70-P74  Transitory endocrine and metabolic disorders s...  P71-P719
#
#                                  level_3_description level_4  \
# 0                                 Hypoparathyroidism     E20
# 1                                 Hypoparathyroidism    E200
# 2                                 Hypoparathyroidism    E201
# 3                                 Hypoparathyroidism    E208
# 4                                 Hypoparathyroidism    E209
# 5  Postproc endocrine and metabolic comp and diso...    E892
# 6  Transitory neonatal disorders of calcium and m...    P714
#
#   icd9_mapped_codes                            icd9_description  \
# 0            No map                                      No map
# 1            No map                                      No map
# 2             27549       Other disorders of calcium metabolism
# 3            No map                                      No map
# 4              2521                          Hypoparathyroidism
# 5            No map                                      No map
# 6              7754  Hypocalcemia and hypomagnesemia of newborn
#
#           level_4_short_description_icd10  \
# 0                      Hypoparathyroidism
# 1           Idiopathic hypoparathyroidism
# 2                Pseudohypoparathyroidism
# 3                Other hypoparathyroidism
# 4          Hypoparathyroidism unspecified
# 5       Postprocedural hypoparathyroidism
# 6  Transitory neonatal hypoparathyroidism
#
#            level_4_long_description_icd10   create_ts   update_ts
# 0                      Hypoparathyroidism  2017-11-02  2017-11-02
# 1           Idiopathic hypoparathyroidism  2017-11-02  2017-11-02
# 2                Pseudohypoparathyroidism  2017-11-02  2017-11-02
# 3                Other hypoparathyroidism  2017-11-02  2017-11-02
# 4          Hypoparathyroidism unspecified  2017-11-02  2017-11-02
# 5       Postprocedural hypoparathyroidism  2017-11-02  2017-11-02
# 6  Transitory neonatal hypoparathyroidism  2017-11-02  2017-11-02

# %%
# %%read_sql
#
# select
#     *
# from
#     RWD_DB.RWD.ICD_GROUPER
# where
#     level_2_description ilike '%disorders%'
#     and level_2_description ilike '%endocrine%'
#     and level_2_description ilike '%glands%'
# Out:
# Query started at 01:33:08 PM India Standard Time; Query executed in 0.06 m
#        id       level_1                           level_1_description  \
# 0    4300  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 1    4301  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 2    4302  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 3    4303  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 4    4304  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 5    4305  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 6    4306  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 7    4307  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 8    4308  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 9    4309  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 10   4310  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 11   4311  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 12   4312  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 13   4313  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 14   4314  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 15   4315  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 16   4316  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 17   4317  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 18   4318  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 19   4319  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 20   4320  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 21   4321  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 22   4322  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 23   4323  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 24   4324  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 25   4325  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 26   4326  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 27   4327  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 28   4328  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 29   4329  E00 -  E8989  Endocrine nutritional and metabolic diseases
# ..    ...           ...                                           ...
# 77   4377  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 78   4378  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 79   4379  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 80   4380  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 81   4381  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 82   4382  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 83   4383  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 84   4384  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 85   4385  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 86   4386  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 87   4387  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 88   4388  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 89   4389  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 90   4390  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 91   4391  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 92   4392  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 93   4393  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 94   4394  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 95   4395  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 96   4396  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 97   4397  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 98   4398  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 99   4399  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 100  4400  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 101  4401  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 102  4402  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 103  4403  E00 -  E8989  Endocrine nutritional and metabolic diseases
# 104  4404  E00 -  E8989  Endocrine nutritional and metabolic diseases
#
# 4                2521                                 Hypoparathyroidism
# 5              No map                                             No map
# 6               25201                        Primary hyperparathyroidism
# 7               25202            Secondary hyperparathyroidism non-renal
# 8               25208                          Other hyperparathyroidism
# 9               25200                    Hyperparathyroidism unspecified
# 10               2528     Other specified disorders of parathyroid gland
# 11               2529          Unspecified disorder of parathyroid gland
# 12             No map                                             No map
# 13               2530                           Acromegaly and gigantism
# 14             No map                                             No map
# 15               2536                 Other disorders of neurohypophysis
# 16               2531  Other and unspecified anterior pituitary hyper...
# 17               2531  Other and unspecified anterior pituitary hyper...
# 18             No map                                             No map
# 19               2532                                 Panhypopituitarism
# 20               2537                     Iatrogenic pituitary disorders
# 21               2535                                 Diabetes insipidus
# 22               2539  Unspecified disorder of the pituitary gland an...
# 23               2534                 Other anterior pituitary disorders
# 24               2539  Unspecified disorder of the pituitary gland an...
# 25             No map                                             No map
# 26               2550                                 Cushing's syndrome
# 27             No map                                             No map
# 28               2550                                 Cushing's syndrome
# 29               2550                                 Cushing's syndrome
# ..                ...                                                ...
# 77               2591  Precocious sexual development and puberty not ...
# 78             No map                                             No map
# 79             No map                                             No map
# 80               2581        Other combinations of endocrine dysfunction
# 81             No map                                             No map
# 82             No map                                             No map
# 83               2588          Other specified polyglandular dysfunction
# 84              25801          Multiple endocrine neoplasia [MEN] type I
# 85              25802        Multiple endocrine neoplasia [MEN] type IIA
# 86              25803        Multiple endocrine neoplasia [MEN] type IIB
# 87               2588          Other specified polyglandular dysfunction
# 88               2589              Polyglandular dysfunction unspecified
# 89             No map                                             No map
# 90               2540                   Persistent hyperplasia of thymus
# 91               2541                                  Abscess of thymus
# 92               2548           Other specified diseases of thymus gland
# 93               2549                Unspecified disease of thymus gland
# 94             No map                                             No map
# 95               2592                                 Carcinoid syndrome
# 96             No map                                             No map
# 97               2593  Ectopic hormone secretion not elsewhere classi...
# 98               2594                  Dwarfism not elsewhere classified
# 99             No map                                             No map
# 100            No map                                             No map
# 101             25950                 Androgen insensitivity unspecified
# 102             25951                    Androgen insensitivity syndrome
# 103             25952                     Partial androgen insensitivity
# 104              2598                Other specified endocrine disorders
# 105              2599                     Unspecified endocrine disorder
# 106            No map                                             No map
#
#                        level_4_short_description_icd10  \
# 0                                   Hypoparathyroidism
# 1                        Idiopathic hypoparathyroidism
# 2                             Pseudohypoparathyroidism
# 3                             Other hypoparathyroidism
# 4                       Hypoparathyroidism unspecified
# 5    Hyperparathyroidism and other disorders of par...
# 6                          Primary hyperparathyroidism
# 7    Secondary hyperparathyroidism not elsewhere cl...
# 8                            Other hyperparathyroidism
# 9                      Hyperparathyroidism unspecified
# 10      Other specified disorders of parathyroid gland
# 11           Disorder of parathyroid gland unspecified
# 12                    Hyperfunction of pituitary gland
# 13                  Acromegaly and pituitary gigantism
# 14                                  Hyperprolactinemia
# 15   Syndrome of inappropriate secretion of antidiu...
# 16              Other hyperfunction of pituitary gland
# 17        Hyperfunction of pituitary gland unspecified
# 18   Hypofunction and other disorders of the pituit...
# 19                                     Hypopituitarism
# 20                        Drug-induced hypopituitarism
# 21                                  Diabetes insipidus
# 22   Hypothalamic dysfunction not elsewhere classified
# 0  Table ST_ADPKD1 successfully created.

# %%
snow.select ("select count (distinct patient_id) from st_adpkd1")
# Out:
#    COUNT (DISTINCT PATIENT_ID)
# 0                        17037

# %% [markdown]
# ## Pelican
# Using table: PELICAN_DIAGNOSIS

# %% [markdown]
# ### Swarali notes:
# There are multiple diagnosis tables. Not sure if we should spend time on getting all relevant records at this stage. Let me know what you think.

# %% [markdown]
# ## Raven

# %%
# %%read_sql
# create or replace table ST_gh1_diag as
# select
# left(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,
# claim_number,
# diagnosis,
# diagnosis_sequence,
# year_of_service
# from
# RWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS
# where
# left (diagnosis, 3) in ('E20')
# or diagnosis in ('2521')
# and year_of_service > '2016-12-31'
# and year_of_service < '2018-01-01'
# Out:
# Query started at 12:00:33 PM GMT Daylight TimeInitiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\botocore\vendored\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_socket.py in recv_into(self, *args, **kwargs)
#     219         try:
# --> 220             return self.connection.recv_into(*args, **kwargs)
#     221         except OpenSSL.SSL.SysCallError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1520         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1521             raise WantReadError()
#    1522         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-30e01bc3c83c> in <module>()
# ----> 1 get_ipython().run_cell_magic('read_sql', '', "create or replace table ST_gh1_diag as\nselect\nleft(encrypted_key_1, 8)||left(encrypted_key_2, 8) as patient_id,\nclaim_number,\ndiagnosis,\ndiagnosis_sequence,\nyear_of_service\nfrom\nRWD_DB.RWD.RAVEN_CLAIMS_SUBMITS_DIAGNOSIS\nwhere\nleft (diagnosis, 3) in ('E20')\nor diagnosis in ('2521')\nand year_of_service > '2016-12-31'\nand year_of_service < '2018-01-01'")
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2165             magic_arg_s = self.var_expand(line, stack_depth)
#    2166             with self.builtin_trap:
# -> 2167                 result = fn(magic_arg_s, cell)
#    2168             return result
#    2169
#
# <decorator-gen-126> in read_sql(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql_magic\sql_magic.py in read_sql(self, line, cell, local_ns)
#     141             t.start()
#     142         else:
# --> 143             result = self.conn.execute_sqls(statements, options)
#     144             if options['display']:
#     145                 return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql_magic\connection.py in execute_sqls(self, sqls, options)
#     144         r = None
#     145         for i, s in enumerate(sqls, start=1):
# --> 146             r = self._read_sql_engine(s, options)
#     147         return r  # return last result
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql_magic\connection.py in _read_sql_engine(self, sql, options)
#     116         if caller is None:
#     117             raise ConnectionNotConfigured("A connection object must be configured using %config SQL.conn_name")
# --> 118         result, del_time, time_output = self._time_and_run_query(caller, sql)
#     119
#     120         if table_name:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql_magic\connection.py in _time_and_run_query(self, caller, sql)
#     132         sys.stdout.write(time_output)
#     133         start_time = time.time()
# --> 134         result = caller(sql)
#     135         end_time = time.time()
#     136         del_time = (end_time - start_time) / 60.
#
# C:\ProgramData\Anaconda3\lib\site-packages\sql_magic\connection.py in _run_db_sql(sql_code)
#      62         def _run_db_sql(sql_code):
#      63             try:
# ---> 64                 return psql.read_sql(sql_code, conn_object)
#      65             except(tuple(self.no_return_result_exceptions)):
#      66                 return EmptyResult()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     395             sql, index_col=index_col, params=params,
#     396             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 397             chunksize=chunksize)
#     398
#     399
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1083         args = _convert_params(sql, params)
#    1084
# -> 1085         result = self.execute(*args)
#    1086         columns = result.keys()
#    1087
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#     974     def execute(self, *args, **kwargs):
#     975         """Simple passthrough to SQLAlchemy connectable"""
# --> 976         return self.connectable.execute(*args, **kwargs)
#     977
#     978     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2073
#    2074         connection = self.contextual_connect(close_with_result=True)
# -> 2075         return connection.execute(statement, *multiparams, **params)
#    2076
#    2077     def scalar(self, statement, *multiparams, **params):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     940         """
#     941         if isinstance(object, util.string_types[0]):
# --> 942             return self._execute_text(object, multiparams, params)
#     943         try:
#     944             meth = object._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1102             statement,
#    1103             parameters,
# -> 1104             statement, parameters
#    1105         )
#    1106         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1414                 )
#    1415             else:
# -> 1416                 util.reraise(*exc_info)
#    1417
#    1418         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\cursor.py in execute(self, command, params, timeout, _do_reset, _put_callback, _put_callback_output_stream, _get_callback, _get_callback_output_stream, _statement_params, _is_internal, _no_results, _use_ijson, _is_put_get)
#     477             is_internal=_is_internal,
#     478             _no_results=_no_results,
# --> 479             _is_put_get=_is_put_get)
#     480         self._sfqid = ret[u'data'][
#     481             u'queryId'] if u'data' in ret and u'queryId' in ret[
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\cursor.py in _execute_helper(self, query, timeout, statement_params, binding_params, is_internal, _no_results, _is_put_get)
#     366                 statement_params=statement_params,
#     367                 is_internal=is_internal,
# --> 368                 _no_results=_no_results)
#     369         finally:
#     370             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\connection.py in cmd_query(self, sql, sequence_counter, request_id, binding_params, is_file_transfer, statement_params, is_internal, _no_results)
#     650         ret = self.rest.request(
#     651             u'/queries/v1/query-request?' + urlencode(url_parameters),
# --> 652             data, client=client, _no_results=_no_results)
#     653
#     654         if ret is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\network.py in request(self, url, body, method, client, _no_results)
#     243                 url, headers, json.dumps(body),
#     244                 token=self._token, _no_results=_no_results,
# --> 245                 timeout=self._connection.network_timeout)
#     246         else:
#     247             return self._get_request(
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\network.py in _post_request(self, url, headers, body, token, timeout, _no_results, no_retry, socket_timeout)
#     410             logger.debug(u'ping pong starting...')
#     411             ret = self._get_request(
# --> 412                 result_url, headers, token=self._token, timeout=timeout)
#     413             logger.debug(u'ret[code] = %s', ret.get(u'code', u'N/A'))
#     414             logger.debug(u'ping pong done')
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\network.py in _get_request(self, url, headers, token, timeout, socket_timeout)
#     355         )
#     356         ret = self.fetch(u'get', full_url, headers, timeout=timeout,
# --> 357                          token=token, socket_timeout=socket_timeout)
#     358         if ret.get(u'code') == SESSION_EXPIRED_GS_CODE:
#     359             ret = self._renew_session()
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\network.py in fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     449                 ret = self._request_exec_wrapper(
#     450                     session, method, full_url, headers, data, retry_ctx,
# --> 451                     **kwargs)
#     452                 if ret is not None:
#     453                     return ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\network.py in _request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     475                 proxies=proxies,
#     476                 token=token,
# --> 477                 **kwargs)
#     478             if return_object is not None:
#     479                 return return_object
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\network.py in _request_exec(self, session, method, full_url, headers, data, proxies, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, is_raw_binary_iterator, use_ijson, socket_timeout)
#     605                 verify=True,
#     606                 stream=is_raw_binary,
# --> 607                 auth=SnowflakeAuth(token),
#     608             )
#     609             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\botocore\vendored\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     463         }
#     464         send_kwargs.update(settings)
# --> 465         resp = self.send(prep, **send_kwargs)
#     466
#     467         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\botocore\vendored\requests\sessions.py in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\botocore\vendored\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# C:\ProgramData\Anaconda3\lib\site-packages\botocore\vendored\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\botocore\vendored\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
# --> 374                 httplib_response = conn.getresponse()
#     375         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     376             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_socket.py in recv_into(self, *args, **kwargs)
#     230                 raise
#     231         except OpenSSL.SSL.WantReadError:
# --> 232             rd = wait_for_read(self.socket, self.socket.gettimeout())
#     233             if not rd:
#     234                 raise timeout('The read operation timed out')
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_util.py in wait_for_read(socks, timeout)
#     616     or optionally a single socket if passed in. Returns a list of
#     617     sockets that can be read from immediately. """
# --> 618     return _wait_for_io_events(socks, EVENT_READ, timeout)
#     619
#     620
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_util.py in _wait_for_io_events(socks, events, timeout)
#     609             selector.register(sock, events)
#     610         return [key[0].fileobj for key in
# --> 611                 selector.select(timeout) if key[1] & events]
#     612
#     613
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_util.py in select(self, timeout)
#     328             ready = []
#     329             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 330                                        self._writers, timeout)
#     331             r = set(r)
#     332             w = set(w)
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_util.py in _syscall_wrapper(func, _, *args, **kwargs)
#      72         and recalculate their timeouts. """
#      73         try:
# ---> 74             return func(*args, **kwargs)
#      75         except (OSError, IOError, select.error) as e:
#      76             errcode = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\ssl_wrap_util.py in _select(self, r, w, timeout)
#     318         def _select(self, r, w, timeout=None):
#     319             """ Wrapper for select.select because timeout is a positional arg """
# --> 320             return select.select(r, w, [], timeout)
#     321
#     322         def select(self, timeout=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\cursor.py in abort_exit(*_)
#     348                         # ignore failures
#     349                         pass
# --> 350             raise KeyboardInterrupt
#     351
#     352         try:
#
# KeyboardInterrupt:

# %%
snow.select ("select count (distinct patient_id) from ST_gh1_diag where left(patient_id, 5) != 'XXX -' and diagnosis_sequence = '1'")
# Out:
#    COUNT (DISTINCT PATIENT_ID)
# 0                        28532
